# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
epsilon = 1

while 1 + epsilon != 1:
    epsilon *= 0.5
    
print(epsilon)
# Out:
# 1.1102230246251565e-16

# %%
def epsilon(x):
    return np.sin(x) - (x- x**3/6.)

# %%
x = 3*np.pi/4
print(epsilon(x)/epsilon(x/2))
# Out:
# 29.021192005921073

# %%
def Function(x):
    return np.sin(x)

# %%
def ExactDerivative(x):
    return np.cos(x)

# %%
EDerivative = ExactDerivative(x)

# %%
N = 50
x = np.linspace(0,2*np.pi,N)
h = x[1] - x[0]
h
# Out:
# 0.1282282715750936

# %%
y = Function(x)

# %%
plt.scatter(x,y)

# %%
def DerivadaDerecha(f,x,h):
    
    d = 0.
    
    if h != 0:
        d = (f(x+h) - f(x))/h
        
    return d

# %%
RDerivative = DerivadaDerecha(Function,x,h)

# %%
plt.plot(x,EDerivative)
plt.plot(x,RDerivative)
